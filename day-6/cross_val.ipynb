# %%
#https://www.kaggle.com/datasets/nikhil7280/student-performance-multiple-linear-regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Set the style
plt.style.use('fivethirtyeight')

df = pd.read_csv('/content/Student_Performance.csv') # Read the dataset.
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
df['Performance Index'].describe()
# Out:
# count    10000.000000
# mean        55.224800
# std         19.212558
# min         10.000000
# 25%         40.000000
# 50%         55.000000
# 75%         71.000000
# max        100.000000
# Name: Performance Index, dtype: float64

# %%
df['Extracurricular Activities'].value_counts()
# Out:
# Extracurricular Activities
# No     5052
# Yes    4948
# Name: count, dtype: int64

# %%
df['Extracurricular Activities'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Extracurricular Activities'] = df['Extracurricular Activities'].map({'Yes':1,'No':0})

# %%
df['Extracurricular Activities'].unique()
# Out:
# array([1, 0])

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  int64
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 468.9 KB

# %%
X = df.drop(columns=['Performance Index'])
X.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2
# 2                                 2
# 3                                 2
# 4                                 5

# %%
y = df[['Performance Index']]
y.head()
# Out:
#    Performance Index
# 0               91.0
# 1               65.0
# 2               45.0
# 3               36.0
# 4               66.0

# %%
df.shape
# Out:
# (10000, 6)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape, y_train.shape
# Out:
# ((8000, 5), (8000, 1))

# %%
X_test.shape, y_test.shape
# Out:
# ((2000, 5), (2000, 1))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(n_jobs=-1)
lr.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
df.columns[:-1]
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced'],
#       dtype='object')

# %%
lr.coef_[0]
# Out:
# array([22.85781679, 60.05490405,  0.60675845,  2.35644259,  1.74286811])

# %%
coeff = pd.DataFrame()
coeff['columns'] = df.columns[:-1]
coeff['weights'] = lr.coef_[0]
coeff
# Out:
#                             columns    weights
# 0                     Hours Studied  22.857817
# 1                   Previous Scores  60.054904
# 2        Extracurricular Activities   0.606758
# 3                       Sleep Hours   2.356443
# 4  Sample Question Papers Practiced   1.742868

# %%
y_pred_test = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mean_squared_error(y_test,y_pred_test)
# Out:
# 4.1979217180548485

# %%
mean_absolute_error(y_test,y_pred_test)
# Out:
# 1.6208765806438097

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.01)
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.01)

# %%
coeff = pd.DataFrame()
coeff['columns'] = df.columns[:-1]
coeff['weights'] = lasso.coef_[0]
coeff
# Out:
#                             columns    weights
# 0                     Hours Studied  22.762686
# 1                   Previous Scores  22.762686
# 2        Extracurricular Activities  22.762686
# 3                       Sleep Hours  22.762686
# 4  Sample Question Papers Practiced  22.762686

# %%
y_pred_test = lasso.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mean_squared_error(y_test,y_pred_test)
# Out:
# 4.207553567144163

# %%
mean_absolute_error(y_test,y_pred_test)
# Out:
# 1.6230545588920853

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
coeff = pd.DataFrame()
coeff['columns'] = df.columns[:-1]
coeff['weights'] = ridge.coef_[0]
coeff
# Out:
#                             columns    weights
# 0                     Hours Studied  22.829774
# 1                   Previous Scores  22.829774
# 2        Extracurricular Activities  22.829774
# 3                       Sleep Hours  22.829774
# 4  Sample Question Papers Practiced  22.829774

# %%
y_pred_test = ridge.predict(X_test)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors = 11,
                        weights = 'distance')
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=11, weights='distance')

# %%
y_pred_test = knn.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mean_squared_error(y_test,y_pred_test)
# Out:
# 8.407120853286257

# %%
mean_absolute_error(y_test,y_pred_test)
# Out:
# 2.3015404582066252

# %%
# param_grid = {'alpha':[0.01,0.1,1,10,100]}

param_grid = {'n_neighbors':[1,3,5,7,11],
              'weights':['uniform','distance'],
              'p':[1,2,3]}

# %%
from sklearn.model_selection import GridSearchCV
grid_serach_cv = GridSearchCV(knn,
                              param_grid,
                              scoring='neg_median_absolute_error',
                              n_jobs=-1,
                              cv=3)

# %%
grid_serach_cv
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'n_neighbors': [1, 3, 5, 7, 11], 'p': [1, 2, 3],
#                          'weights': ['uniform', 'distance']},
#              scoring='neg_median_absolute_error')

# %%
grid_serach_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'n_neighbors': [1, 3, 5, 7, 11], 'p': [1, 2, 3],
#                          'weights': ['uniform', 'distance']},
#              scoring='neg_median_absolute_error')

# %%
grid_serach_cv.best_params_
# Out:
# {'n_neighbors': 11, 'p': 2, 'weights': 'distance'}
