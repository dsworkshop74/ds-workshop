# %%
import pandas as pd
import numpy as np

# %%
np.random.randn(10,4)
# Out:
# array([[-0.3449032 , -0.98942937,  0.27111137, -0.99490655],
#        [ 0.59493967, -0.93391611,  0.16382667, -0.06743349],
#        [-0.41287461, -0.5400253 ,  1.92529291,  0.90974413],
#        [-1.37486688,  0.75118686, -0.55514478,  0.00288213],
#        [ 0.90956178,  0.84254084,  0.3732857 ,  0.0467988 ],
#        [-1.79602517,  0.46047321,  1.16335603,  0.13976801],
#        [ 0.81445696,  1.24387063, -0.84374789, -0.38582406],
#        [-0.18627627,  1.15654206,  0.14789844, -1.13840323],
#        [ 2.06155013, -0.09591672,  0.94464565, -0.74662393],
#        [-0.96438033,  1.25307578,  0.38399303, -1.13198413]])

# %%
np.random.seed(101)
np.random.randn(10,4)
# Out:
# array([[ 2.70684984,  0.62813271,  0.90796945,  0.50382575],
#        [ 0.65111795, -0.31931804, -0.84807698,  0.60596535],
#        [-2.01816824,  0.74012206,  0.52881349, -0.58900053],
#        [ 0.18869531, -0.75887206, -0.93323722,  0.95505651],
#        [ 0.19079432,  1.97875732,  2.60596728,  0.68350889],
#        [ 0.30266545,  1.69372293, -1.70608593, -1.15911942],
#        [-0.13484072,  0.39052784,  0.16690464,  0.18450186],
#        [ 0.80770591,  0.07295968,  0.63878701,  0.3296463 ],
#        [-0.49710402, -0.7540697 , -0.9434064 ,  0.48475165],
#        [-0.11677332,  1.9017548 ,  0.23812696,  1.99665229]])

# %%
'W X Y Z'.split()
# Out:
# ['W', 'X', 'Y', 'Z']

# %%
np.random.seed(101)
df = pd.DataFrame(np.random.randn(10,4),columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509
# 5  0.302665  1.693723 -1.706086 -1.159119
# 6 -0.134841  0.390528  0.166905  0.184502
# 7  0.807706  0.072960  0.638787  0.329646
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %%
df.head()
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509

# %%
df.head(2)
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965

# %%
df
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509
# 5  0.302665  1.693723 -1.706086 -1.159119
# 6 -0.134841  0.390528  0.166905  0.184502
# 7  0.807706  0.072960  0.638787  0.329646
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %%
df.tail()
# Out:
#           W         X         Y         Z
# 5  0.302665  1.693723 -1.706086 -1.159119
# 6 -0.134841  0.390528  0.166905  0.184502
# 7  0.807706  0.072960  0.638787  0.329646
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %%
df.tail(2)
# Out:
#           W         X         Y         Z
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.shape
# Out:
# (10, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       10 non-null     float64
#  1   X       10 non-null     float64
#  2   Y       10 non-null     float64
#  3   Z       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
df
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509
# 5  0.302665  1.693723 -1.706086 -1.159119
# 6 -0.134841  0.390528  0.166905  0.184502
# 7  0.807706  0.072960  0.638787  0.329646
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %%
df.describe()
# Out:
#                W          X          Y          Z
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.208094   0.557372   0.065576   0.399579
# std     1.177846   1.034991   1.235387   0.847120
# min    -2.018168  -0.758872  -1.706086  -1.159119
# 25%    -0.130324  -0.221249  -0.911947   0.220788
# 50%     0.189745   0.509330   0.202516   0.494289
# 75%     0.564005   1.455323   0.611294   0.664123
# max     2.706850   1.978757   2.605967   1.996652

# %%
'A B C D E F G H I J'.split()
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
df = pd.DataFrame(np.random.randn(10,4),
                  index='A B C D E F G H I J'.split(),
                  columns='W X Y Z'.split())
df.head()
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %% [markdown]
# ## Selection and Indexing

# %%
df[['W']]
# Out:
# A   -0.993263
# B    1.025984
# C    2.154846
# D    0.147027
# E   -0.925874
# F    0.386030
# G    0.681209
# H   -1.005187
# I   -1.382920
# J    0.992573
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
# Pass a list of column names
df[['W','Z']]
# Out:
#           W         Z
# A -0.993263  0.000366
# B  1.025984  0.649826
# C  2.154846 -0.346419
# D  0.147027  1.024810
# E -0.925874  0.610478
# F  0.386030  0.230336
# G  0.681209  1.939932
# H -1.005187 -0.732845
# I -1.382920 -2.141212
# J  0.992573  1.292765

# %%
type(df[['W', 'Z']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.W #df['W']

# %%
# SQL Syntax (NOT RECOMMENDED!)
df.full name
df['full name']
# Out:
#   File "<ipython-input-71-6257b4719d4a>", line 3
#     df.full name
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Creating a new column:**

# %%
-0.993 + -1.136645
# Out:
# -2.129645

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478
# F  0.386030  2.084019 -0.376519  0.230336
# G  0.681209  1.035125 -0.031160  1.939932
# H -1.005187 -0.741790  0.187125 -0.732845
# I -1.382920  1.482495  0.961458 -2.141212
# J  0.992573  1.192241 -1.046780  1.292765

# %%
df['new'] = df['W'] + df['Y'] # can perform any arithmatic operation
df.head()
# Out:
#           W         X         Y         Z       new
# A -0.993263  0.196800 -1.136645  0.000366 -2.129908
# B  1.025984 -0.156598 -0.031579  0.649826  0.994405
# C  2.154846 -0.610259 -0.755325 -0.346419  1.399521
# D  0.147027 -0.479448  0.558769  1.024810  0.705796
# E -0.925874  1.862864 -1.133817  0.610478 -2.059691

# %%
df['new2'] = df['W']**2 + df['Y'] + df['W'] + df['X'] # can perform any arithmatic operation
df.head()
# Out:
#           W         X         Y         Z       new      new2
# A -0.993263  0.196800 -1.136645  0.000366 -2.129908 -0.946536
# B  1.025984 -0.156598 -0.031579  0.649826  0.994405  1.890451
# C  2.154846 -0.610259 -0.755325 -0.346419  1.399521  5.432625
# D  0.147027 -0.479448  0.558769  1.024810  0.705796  0.247965
# E -0.925874  1.862864 -1.133817  0.610478 -2.059691  0.660416

# %%
df['new3'] = 45
df.head()
# Out:
#           W         X         Y         Z       new      new2  new3
# A -0.993263  0.196800 -1.136645  0.000366 -2.129908 -0.946536    45
# B  1.025984 -0.156598 -0.031579  0.649826  0.994405  1.890451    45
# C  2.154846 -0.610259 -0.755325 -0.346419  1.399521  5.432625    45
# D  0.147027 -0.479448  0.558769  1.024810  0.705796  0.247965    45
# E -0.925874  1.862864 -1.133817  0.610478 -2.059691  0.660416    45

# %%
df['new3'].unique()
# Out:
# array([45])

# %%
df['new3'].nunique()
# Out:
# 1

# %%
df

# %%
df.max(axis=0)
# Out:
# W        2.154846
# X        2.084019
# Y        0.961458
# Z        1.939932
# new      1.399521
# new2     5.432625
# new3    45.000000
# dtype: float64

# %%
df.max(axis=1)
# Out:
# A    45.0
# B    45.0
# C    45.0
# D    45.0
# E    45.0
# F    45.0
# G    45.0
# H    45.0
# I    45.0
# J    45.0
# dtype: float64

# %%
df['W'].max()
# Out:
# 2.154846443259472

# %%
df['W'].mean()
# Out:
# 0.10804256502627649

# %%
df[['W','Y']].sum()

# %%
df['W'].median()
# Out:
# 0.26652854171883766

# %%
df['W'].std()
# Out:
# 1.153056007555865

# %% [markdown]
# ** Removing Columns**

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z      new2  new3
# A -0.993263  0.196800 -1.136645  0.000366 -0.946536    45
# B  1.025984 -0.156598 -0.031579  0.649826  1.890451    45
# C  2.154846 -0.610259 -0.755325 -0.346419  5.432625    45
# D  0.147027 -0.479448  0.558769  1.024810  0.247965    45
# E -0.925874  1.862864 -1.133817  0.610478  0.660416    45
# F  0.386030  2.084019 -0.376519  0.230336  2.242550    45
# G  0.681209  1.035125 -0.031160  1.939932  2.149220    45
# H -1.005187 -0.741790  0.187125 -0.732845 -0.549451    45
# I -1.382920  1.482495  0.961458 -2.141212  2.973502    45
# J  0.992573  1.192241 -1.046780  1.292765  2.123237    45

# %%
df
# Out:
#           W         X         Y         Z       new      new2  new3
# A -0.993263  0.196800 -1.136645  0.000366 -2.129908 -0.946536    45
# B  1.025984 -0.156598 -0.031579  0.649826  0.994405  1.890451    45
# C  2.154846 -0.610259 -0.755325 -0.346419  1.399521  5.432625    45
# D  0.147027 -0.479448  0.558769  1.024810  0.705796  0.247965    45
# E -0.925874  1.862864 -1.133817  0.610478 -2.059691  0.660416    45
# F  0.386030  2.084019 -0.376519  0.230336  0.009512  2.242550    45
# G  0.681209  1.035125 -0.031160  1.939932  0.650049  2.149220    45
# H -1.005187 -0.741790  0.187125 -0.732845 -0.818062 -0.549451    45
# I -1.382920  1.482495  0.961458 -2.141212 -0.421462  2.973502    45
# J  0.992573  1.192241 -1.046780  1.292765 -0.054206  2.123237    45

# %%
df = df.drop('new',axis=1) # Axis 0 means rows, axis 1 means columns
df
# Out:
#           W         X         Y         Z      new2  new3
# A -0.993263  0.196800 -1.136645  0.000366 -0.946536    45
# B  1.025984 -0.156598 -0.031579  0.649826  1.890451    45
# C  2.154846 -0.610259 -0.755325 -0.346419  5.432625    45
# D  0.147027 -0.479448  0.558769  1.024810  0.247965    45
# E -0.925874  1.862864 -1.133817  0.610478  0.660416    45
# F  0.386030  2.084019 -0.376519  0.230336  2.242550    45
# G  0.681209  1.035125 -0.031160  1.939932  2.149220    45
# H -1.005187 -0.741790  0.187125 -0.732845 -0.549451    45
# I -1.382920  1.482495  0.961458 -2.141212  2.973502    45
# J  0.992573  1.192241 -1.046780  1.292765  2.123237    45

# %%
df = df.drop(['new2','new3'],axis=1)
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478
# F  0.386030  2.084019 -0.376519  0.230336
# G  0.681209  1.035125 -0.031160  1.939932
# H -1.005187 -0.741790  0.187125 -0.732845
# I -1.382920  1.482495  0.961458 -2.141212
# J  0.992573  1.192241 -1.046780  1.292765

# %% [markdown]
# Can also drop rows this way:

# %%
df = df.drop('E',axis=0)
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# F  0.386030  2.084019 -0.376519  0.230336
# G  0.681209  1.035125 -0.031160  1.939932
# H -1.005187 -0.741790  0.187125 -0.732845
# I -1.382920  1.482495  0.961458 -2.141212
# J  0.992573  1.192241 -1.046780  1.292765

# %%
df = df.drop(['F','G','H','I','J'],axis=0)
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %% [markdown]
# ** Selecting Rows**

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df.loc['A']
# Out:
# W   -0.993263
# X    0.196800
# Y   -1.136645
# Z    0.000366
# Name: A, dtype: float64

# %%
df.loc[['A','B']]
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df.iloc[2]
# Out:
# W    2.154846
# X   -0.610259
# Y   -0.755325
# Z   -0.346419
# Name: C, dtype: float64

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df.iloc[2:5]
# Out:
#           W         X         Y         Z
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df.iloc[1::2]
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# D  0.147027 -0.479448  0.558769  1.024810

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df.loc['B','Y']
# Out:
# -0.031579143908112575

# %%
df.iloc[1,2]
# Out:
# -0.031579143908112575

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A -0.993263 -1.136645
# B  1.025984 -0.031579

# %%
# df.iloc[['A','B'],['W','Y']]

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df > 0
# Out:
#        W      X      Y      Z
# A  False   True  False   True
# B   True  False  False   True
# C   True  False  False  False
# D   True  False   True   True

# %%
df['W'] > 0
# Out:
# A    False
# B     True
# C     True
# D     True
# Name: W, dtype: bool

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df[df['W'] > 0]
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
# df[df['Pclass'] == 1]

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
(df['W'] > 0)
# Out:
# A    False
# B     True
# C     True
# D     True
# Name: W, dtype: bool

# %%
(df['Y'] > 0)
# Out:
# A    False
# B    False
# C    False
# D     True
# Name: Y, dtype: bool

# %%
(df['W'] > 0) & (df['Y'] > 0)
# Out:
# A    False
# B    False
# C    False
# D     True
# dtype: bool

# %%
df[(df['W'] > 0) & (df['Y'] > 0)]
# Out:
#           W         X         Y        Z
# D  0.147027 -0.479448  0.558769  1.02481

# %%
df[(df['W'] > 0) | (df['Y'] > 1)]
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %% [markdown]
# ## More Index Details
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
# Reset to default 0,1...n index
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A -0.993263  0.196800 -1.136645  0.000366
# 1     B  1.025984 -0.156598 -0.031579  0.649826
# 2     C  2.154846 -0.610259 -0.755325 -0.346419
# 3     D  0.147027 -0.479448  0.558769  1.024810

# %%
newind = 'CA NY WY NY'.split()
newind
# Out:
# ['CA', 'NY', 'WY', 'NY']

# %%
df['States'] = newind

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.993263  0.196800 -1.136645  0.000366     CA
# B  1.025984 -0.156598 -0.031579  0.649826     NY
# C  2.154846 -0.610259 -0.755325 -0.346419     WY
# D  0.147027 -0.479448  0.558769  1.024810     NY

# %%
df['States'].value_counts()
# Out:
# States
# NY    2
# CA    1
# WY    1
# Name: count, dtype: int64

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA     -0.993263  0.196800 -1.136645  0.000366
# NY      1.025984 -0.156598 -0.031579  0.649826
# WY      2.154846 -0.610259 -0.755325 -0.346419
# NY      0.147027 -0.479448  0.558769  1.024810

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.993263  0.196800 -1.136645  0.000366     CA
# B  1.025984 -0.156598 -0.031579  0.649826     NY
# C  2.154846 -0.610259 -0.755325 -0.346419     WY
# D  0.147027 -0.479448  0.558769  1.024810     NY

# %% [markdown]
# # Missing Data
#
# Let's show a few convenient methods to deal with Missing Data in pandas:

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       2 non-null      float64
#  1   B       1 non-null      float64
#  2   C       3 non-null      int64
# dtypes: float64(2), int64(1)
# memory usage: 200.0 bytes

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.isna()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
df.isna()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df.isna().mean()
# Out:
# A    0.333333
# B    0.666667
# C    0.000000
# dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df['B'].dropna()
# Out:
# 0    5.0
# Name: B, dtype: float64

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(thresh=3)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0         1.0         5.0  1
# 1         2.0  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
value=df['A'].mean()
value
# Out:
# 1.5

# %%
df['B'].fillna(value=df['B'].mean())
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# Name: B, dtype: float64

# %% [markdown]
# # Groupby
#
# The groupby method allows you to group rows of data together and call aggregate functions

# %%
import pandas as pd
# Our data: dictionary of lists

data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# ** Now you can use the .groupby() method to group rows together based off of a column name. For instance let's group based off of Company. This will create a DataFrameGroupBy object:**

# %%
by_comp = df.groupby("Company")['Sales'].mean()

print(by_comp)
# Out:
# Company
# FB      296.5
# GOOG    160.0
# MSFT    232.0
# Name: Sales, dtype: float64

# %%
by_comp = df.groupby("Company")['Sales'].sum()

print(by_comp)
# Out:
# Company
# FB      593
# GOOG    320
# MSFT    464
# Name: Sales, dtype: int64

# %%
by_comp = df.groupby("Company")['Sales'].max()

print(by_comp)
# Out:
# Company
# FB      350
# GOOG    200
# MSFT    340
# Name: Sales, dtype: int64

# %%
by_comp = df.groupby("Company")['Sales'].min()

print(by_comp)
# Out:
# Company
# FB      243
# GOOG    120
# MSFT    124
# Name: Sales, dtype: int64

# %% [markdown]
# ### Example DataFrames

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ## Concatenation

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})

df2 = pd.DataFrame({
    'C': ['a', 'b', 'c'],
    'D': ['x', 'y', 'z']
})

# %%
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df2
# Out:
#    C  D
# 0  a  x
# 1  b  y
# 2  c  z

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    A  B  C  D
# 0  1  4  a  x
# 1  2  5  b  y
# 2  3  6  c  z

# %% [markdown]
# # Operations

# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# ### Applying Functions

# %%
df['col1'] ** 2
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col1, dtype: int64

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
def times2(x):
    return x*2

df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col1'].apply(lambda x:x*2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col3_len'] = df['col3'].apply(len)
df
# Out:
#    col1  col2 col3  col3_len
# 0     1   444  abc         3
# 1     2   555  def         3
# 2     3   666  ghi         3
# 3     4   444  xyz         3

# %% [markdown]
# ** Sorting and Ordering a DataFrame:**

# %%
df
# Out:
#    col1  col2 col3  col3_len
# 0     1   444  abc         3
# 1     2   555  def         3
# 2     3   666  ghi         3
# 3     4   444  xyz         3

# %%
data = {
    'col1': [3, 1, 2, 3, 2],
    'col2': [5, 4, 3, 2, 1],
    'col3': ['A', 'B', 'C', 'D', 'E']
}

df = pd.DataFrame(data)
df
# Out:
#    col1  col2 col3
# 0     3     5    A
# 1     1     4    B
# 2     2     3    C
# 3     3     2    D
# 4     2     1    E

# %%
df.sort_values(by='col2')
# Out:
#    col1  col2 col3
# 4     2     1    E
# 3     3     2    D
# 2     2     3    C
# 1     1     4    B
# 0     3     5    A

# %%
df.sort_values(by='col2',ascending=False)
# Out:
#    col1  col2 col3
# 0     3     5    A
# 1     1     4    B
# 2     2     3    C
# 3     3     2    D
# 4     2     1    E

# %% [markdown]
# # read and write to files

# %%
import pandas as pd

# Step 1: Create a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)

df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
csv_file = 'sample_data.csv'
df.to_csv(csv_file, index=False)

# %%
read_df = pd.read_excel('/content/Titanic-Dataset.xlsx')
read_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#pd.read_csv csv (comma seperated file)
#pd.read_excel .xlsx
#pd.read_html .html

# %%
import pandas as pd
df = pd.read_excel("/content/Titanic-Dataset.xlsx")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
